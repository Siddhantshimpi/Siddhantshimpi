# %% [markdown]
# We're gonna simulate the 'Trappist-1' star system in the vicinity of the constellation of Aquarius. It consists of 7 planets closely orbiting a red dwarf star:

# %%
from IPython.display import Image
Image(filename = r'..\Images\trappist1.jpg')

# %% [markdown]
# # Masses, Radii and Periods (In terms of Terrestrial Parameters):
#
# ## Trappist 1 (Type - M Red Dwarf Star):
# - Mass: 29637.37 X Earth
# - Radius: 13.21 X Earth
#
# ## Trappist 1-b:
# - Mass: 1.374 X Earth
# - Radius: 1.16 X Earth
# - Radius of Orbit: 0.012 AU
# - Orbital Period: 1.5 days
#
# ## Trappist 1-c:
# - Mass: 1.308 X Earth
# - Radius: 1.1 X Earth
# - Radius of Orbit: 0.016 AU
# - Orbital Period: 2.4 days
#
# ## Trappist 1-d:
# - Mass: 0.388 X Earth
# - Radius: 0.79 X Earth
# - Radius of Orbit: 0.022 AU
# - Orbital Period: 4 days
#
# ## Trappist 1-e:
# - Mass: 0.692 X Earth
# - Radius: 0.92 X Earth
# - Radius of Orbit: 0.029 AU
# - Orbital Period: 6.1 days
#
# ## Trappist 1-f:
# - Mass: 1.309 X Earth
# - Radius: 1.045 X Earth
# - Radius of Orbit: 0.038 AU
# - Orbital Period: 9.2 days
#
# ## Trappist 1-g:
# - Mass: 1.321 X Earth
# - Radius: 1.129 X Earth
# - Radius of Orbit: 0.047 AU
# - Orbital Period: 12.4 days
#
# ## Trappist 1-h:
# - Mass: 0.326 X Earth
# - Radius: 0.755 X Earth
# - Radius of Orbit: 0.062 AU
# - Orbital Period: 18.8 days

# %% [markdown]
# Run the local file 'planet_sim.py' in terminal.
