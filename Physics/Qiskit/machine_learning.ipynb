# %%
from qiskit import *
import matplotlib.pyplot as plt, numpy as numpy

from qiskit import BasicAer 
from qiskit_machine_learning.datasets import ad_hoc_data
from qiskit.utils import QuantumInstance

# %% [markdown]
# In this notebook, we'll be implementing a (Quantum) Support Vector Machine (SVM). First we set up a few initial parameters:

# %%
feature_dim = 2
training_datatset = 20
testing_dataset_size = 10

random_seed = 10598
shots = 10000

# %% [markdown]
# Let's set up the data:

# %%
sample_total, training_input, test_input, class_labels = ad_hoc_data(training_datatset, testing_dataset_size, feature_dim, gap = 0.3, plot_data = True)
datapoints, class_to_label = split_dataset_to_data_and_labels(test_input)
print(class_to_label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 sample_total, training_input, test_input, class_labels = ad_hoc_data(training_datatset, testing_dataset_size, feature_dim, gap = 0.3, plot_data = True)
# ----> 2 datapoints, class_to_label = split_dataset_to_data_and_labels(test_input)
#       3 print(class_to_label)
#
# NameError: name 'split_dataset_to_data_and_labels' is not defined
